# %% [markdown]
# <a href="https://colab.research.google.com/github/jamierosereyes/CPE-031-Visualizations-and-Data-Analysis/blob/main/Reyes%2C_Jamie_Rose_KIa_Hands_On_Activity_10___Explaining_Visually_to_Influence_with_Data_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Hands-On Activity 10 | Explaining Visually to Influence with Data**
#
#
#
#
#
# ---

# %% [markdown]
# Name : Reyes, Jamie Rose Kia M.  <br>
# Course Code and Title : CPE 031 - Visualizations and Data Analysis<br>
# Date Submitted : October 2, 2025 <br>
# Instructor : Ms. Maria Rizette Sayo
#
#
# ---

# %% [markdown]
# **1. Objectives:**
#
# This activity aims to help students demonstrate how to influence and communicate effectively with data by identifying audience needs, crafting a clear message, and telling a story visually through charts.

# %% [markdown]
# **2. Intended Learning Outcomes (ILOs):**
#
# By the end of this activity, students should be able to:
#
# 1. Analyze the audience to understand their level of data knowledge and needs.
#
# 2. Evaluate how well a message and visualization communicate insights.
#
# 3. Create a clear and meaningful data story using Python visualization tools.

# %% [markdown]
# **3. Discussions:**
#
# Data storytelling goes beyond showing charts it’s about influencing decisions and sparking understanding.
#
# Know Your Audience: Decision-makers may prefer clear summaries, while analysts like detailed data.
#
# Know Your Message: Focus on the why it matters part of the story.
#
# Tell a Story: Use preattentive attributes color, size, and position to guide attention.
#
# Structure Your Story: Like Aristotle’s rhetorical triangle, combine logic (logos), emotion (pathos), and credibility (ethos).

# %% [markdown]
# **4. Procedures:**

# %% [markdown]
# Step 1. Import Libraries and Create Sample Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample sales dataset
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Sales": [200, 250, 180, 300, 280, 350],
    "Marketing_Spend": [50, 60, 45, 70, 65, 80]
}
df = pd.DataFrame(data)
df
# Out:
#   Month  Sales  Marketing_Spend
# 0   Jan    200               50
# 1   Feb    250               60
# 2   Mar    180               45
# 3   Apr    300               70
# 4   May    280               65
# 5   Jun    350               80

# %% [markdown]
# Step 2. Know Your Audience — Compare Chart Styles

# %%
# Executive audience: prefer clarity (simple bar)
plt.figure(figsize=(7,4))
sns.barplot(x="Month", y="Sales", data=df, color="steelblue")
plt.title("Executive View: Monthly Sales Overview", fontsize=13)
plt.show()

# Analyst audience: prefer detailed trends (line chart)
plt.figure(figsize=(7,4))
sns.lineplot(x="Month", y="Sales", data=df, marker="o", label="Sales")
sns.lineplot(x="Month", y="Marketing_Spend", data=df, marker="o", label="Marketing Spend")
plt.title("Analyst View: Sales vs Marketing Trend", fontsize=13)
plt.legend()
plt.show()

# %% [markdown]
# **Task 1:** Create one additional visualization suited for a different audience (e.g., a customer, investor, or teammate).

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample sales dataset
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Sales": [200, 250, 180, 300, 280, 350],
    "Marketing_Spend": [50, 60, 45, 70, 65, 80]
}
df = pd.DataFrame(data)


# Investor audience: prefer ROI insights (scatter plot)
plt.figure(figsize=(7,4))
sns.scatterplot(x="Marketing_Spend", y="Sales", data=df)
plt.title("Investor View: Sales vs Marketing Spend (ROI Insight)", fontsize=13)
plt.xlabel("Marketing Spend ($)")
plt.ylabel("Sales ($)")
plt.show()

# %% [markdown]
# Step 3. Know Your Message — Highlight What Matters

# %%
# Highlight the highest sales month (preattentive color cue)
highlight = df["Sales"].idxmax()

colors = ["gray" if i != highlight else "crimson" for i in range(len(df))]
plt.figure(figsize=(7,4))
plt.bar(df["Month"], df["Sales"], color=colors)
plt.title("Highlighting the Best Month in Sales", fontsize=13)
plt.show()

# %% [markdown]
# **Task 2:** Use color or annotations to emphasize a key insight (e.g., lowest point, sudden increase).

# %%
# Highlight the lowest sales month (preattentive color cue)
highlight = df["Sales"].idxmin()

colors = ["gray" if i != highlight else "green" for i in range(len(df))]
plt.figure(figsize=(7,4))
plt.bar(df["Month"], df["Sales"], color=colors)
plt.title("Highlighting the Lowest Month in Sales", fontsize=13)
plt.show()

# %% [markdown]
# Step 4. Storytelling with Charts — Beginning, Middle, End

# %%
# Beginning: Context
plt.figure(figsize=(7,4))
sns.barplot(x="Month", y="Sales", data=df, color="skyblue")
plt.title("Beginning: Sales Started Steady", fontsize=13)
plt.show()

# Middle: Change or Challenge
plt.figure(figsize=(7,4))
sns.lineplot(x="Month", y="Sales", data=df, color="orange", marker="o")
plt.title("Middle: A Drop in March Due to Low Marketing", fontsize=13)
plt.show()

# End: Resolution
plt.figure(figsize=(7,4))
sns.barplot(x="Month", y="Sales", data=df, color="limegreen")
plt.title("End: Recovery and Growth After March", fontsize=13)
plt.show()

# %% [markdown]
# **Task 3:** Write one or two lines describing your data story from beginning → middle → end.

# %% [markdown]
# Beginning: Sales started steady at the beginning of the year.<br>
# Middle: In March, there was a dip in sales, potentially due to lower marketing spend that month. <br>
# End: Following the dip, sales recovered and showed growth in the subsequent months. <br>

# %% [markdown]
# Step 5. Bringing It All Together — Presentation Design

# %%
# Simple combined story chart
plt.figure(figsize=(8,5))
sns.lineplot(x="Month", y="Sales", data=df, marker="o", linewidth=2, color="royalblue", label="Sales")
sns.lineplot(x="Month", y="Marketing_Spend", data=df, marker="o", linestyle="--", color="orange", label="Marketing Spend")

plt.fill_between(df["Month"], df["Sales"], alpha=0.1, color="royalblue")
plt.title("From Effort to Impact: Marketing Spend Drives Sales Growth", fontsize=13)
plt.legend()
plt.show()

# %% [markdown]
# ---
#
#
# **5. Supplementary Activity:**

# %% [markdown]
# 1. Use a small dataset available online (kaggle, google dataset, etc.).
#
# 2. Visualize it using a bar chart.
#
# 3. Highlight one important data point (e.g., the highest or lowest value) using a distinct color.
#
# 4. Add a title and annotation that tell the story behind the data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/CPE 031_REYES, JAMIE/HOA 10/vgsales.csv")

df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
# Sort the dataframe by Global_Sales in descending order and select the top 10
top_10_games = df.sort_values(by='Global_Sales', ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x='Global_Sales', y='Name', data=top_10_games, palette='viridis')
plt.title('Top 10 Best-Selling Video Games Globally', fontsize=16)
plt.xlabel('Global Sales (Millions)', fontsize=12)
plt.ylabel('Game Title', fontsize=12)
plt.show()
# Out:
# /tmp/ipython-input-3372879545.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Global_Sales', y='Name', data=top_10_games, palette='viridis')

# %% [markdown]
# 4.) This bar chart displays the top 10 best-selling video games globally based on their total sales. The y-axis shows the game titles, while the x-axis shows the global sales in millions.
#
# In here, we can see that "Wii Sports" has the highest global sales, showing a big gap from other games in the top 10. The chart also shows the relative sales of the other games in the top 10, allowing for a quick comparison of their performance. The annotation on the "Wii Sports" bar provides the exact global sales figure for that game.

# %% [markdown]
# **6. Conclusion/Learnings/Analysis:**

# %% [markdown]
# This activity showed me the importance of creating data visualizations with a considerations to the specific audiences to effectively communicate what is happening on the data. By analyzing audience needs and choosing appropriate chart styles, we can ensure the message can be conveyed in a way that the audience will be able to understand and can be impactful to them. Highlighting key data points using color or annotations helps to draw attention to important information and can help the viewer's understanding. Finally, creating the visualization that has a clear beginning, middle, and end allows for a more engaging and memorable data story that can influence decisions and generate understanding. The supplementary activity demonstrated these principles by visualizing a real-world dataset and highlighting the most important parts with annotations.
